# %%
from deepface import DeepFace

DeepFace.represent(
    img_path=r"C:\Users\attam\OneDrive\Pictures\host.png",
    model_name="Facenet",
    # detector_backend="skip",
    # enforce_detection=False,
    # align=False,
    anti_spoofing=True,
    normalization="Facenet",
    l2_normalize=True,  # normize output embedding
)
# Out:
# [{'embedding': [-0.006601448492630509,
#    -0.02788015694242544,
#    0.034381187650474175,
#    0.09338715344237235,
#    -0.008717051821528052,
#    -0.10108790449447293,
#    -0.11091805356841801,
#    0.027666017308272586,
#    0.08651498215372128,
#    0.06268105993722488,
#    0.08456173254825038,
#    -0.022251846938524396,
#    -0.04618475139854127,
#    -0.029961810893385375,
#    -0.06674078044220164,
#    0.1046822501040811,
#    0.17201394389684802,
#    -0.02246170850455971,
#    -0.09637240391191568,
#    -0.047369334961529175,
#    0.07767786925789943,
#    -0.11575699510675513,
#    0.10407781722757152,
#    0.12325533746512952,
#    -0.0637515686061854,
#    -0.08384869696678611,
#    -0.04066711563986059,
#    0.0272733358240056,
#    0.05671362736980993,
#    -0.09741821504442578,
#    -0.15013655771436427,
#    0.011754532103283071,
#    -0.12010543329136336,
#    0.06549828201288953,
#    0.007395431846298775,
#    0.09952867326955575,
# ...

# %%
from deepface import DeepFace

DeepFace.represent(
    img_path=r"C:\Users\attam\OneDrive\Pictures\host.png",
    model_name="Facenet",
    detector_backend="skip",
    enforce_detection=False,
    # align=False,
    anti_spoofing=True,
    normalization="Facenet",
    l2_normalize=True,  # normize output embedding
)
# Out:
# [{'embedding': [-0.04619584408974267,
#    -0.07464371397029652,
#    0.0437760730478642,
#    -0.06670382986109467,
#    0.028146206257619065,
#    0.118750410556458,
#    -0.034137158806551035,
#    0.05493839334159883,
#    0.06847848129761072,
#    0.06152619205159697,
#    0.16643612579812353,
#    -0.05827228965549669,
#    0.05773734676211902,
#    -0.18421382962716845,
#    -0.041699821986315076,
#    -0.040590866345399296,
#    0.05643015329645879,
#    -0.007789812489026448,
#    0.005137098598107349,
#    -0.07295542164828916,
#    -0.036163159407542826,
#    0.03685535725314514,
#    -0.12145393099781014,
#    0.03708210700794009,
#    0.02019007187040069,
#    -0.01415044286335897,
#    0.09076403127484331,
#    0.14190364754448725,
#    -0.20670709257794534,
#    -0.02361831838815651,
#    -0.005955300528657715,
#    0.09966855402692082,
#    -0.06565891363404626,
#    -0.08170075913305247,
#    0.046997312298667604,
#    0.06649781888580139,
#    -0.05344505938429128,
# ...

# %%
from deepface import DeepFace

DeepFace.represent(
    img_path=r"C:\Users\attam\OneDrive\Pictures\host.png",
    model_name="Facenet",
    # detector_backend="skip",
    # enforce_detection=False,
    align=False,
    anti_spoofing=True,
    normalization="Facenet",
    l2_normalize=True,  # normize output embedding
)
# Out:
# [{'embedding': [-0.025427777944577415,
#    -0.024324668719221763,
#    0.03848254284602901,
#    0.07216105604713498,
#    -0.02362051423201611,
#    -0.1127904055618715,
#    -0.12523442878439908,
#    0.0013915143443173422,
#    0.08129039927282365,
#    0.050596693550751665,
#    0.04617190749701364,
#    -0.021807275123173153,
#    -0.03724201482772434,
#    -0.011875581731383707,
#    -0.04638499932133463,
#    0.08048950209838283,
#    0.17947779943513917,
#    -0.02258176819609592,
#    -0.08512638407706156,
#    -0.08210703676464913,
#    0.06054812873256395,
#    -0.09007233704443826,
#    0.11672761970773214,
#    0.10290535345772493,
#    -0.06202649795158352,
#    -0.05204025225604839,
#    -0.0739365505694655,
#    0.009609327146364822,
#    0.07775471643556096,
#    -0.12024923227426325,
#    -0.17855278766203453,
#    -0.01247806127583367,
#    -0.1300895046565316,
#    0.08550411083688278,
#    0.06201320397165092,
#    0.12473562108864167,
# ...

# %%
from deepface import DeepFace

DeepFace.represent(
    img_path=r"C:\Users\attam\OneDrive\Pictures\chad_icon.jpg",
    model_name="Facenet",
    # detector_backend="skip",
    # enforce_detection=False,
    # align=False,
    anti_spoofing=True,
    normalization="Facenet",
    l2_normalize=True,  # normize output embedding
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from deepface import DeepFace
# ----> 3 DeepFace.represent(
#       4     img_path=r"C:\Users\attam\OneDrive\Pictures\chad_icon.jpg",
#       5     model_name="Facenet",
#       6     # detector_backend="skip",
#       7     # enforce_detection=False,
#       8     # align=False,
#       9     anti_spoofing=True,
#      10     normalization="Facenet",
#      11     l2_normalize=True,  # normize output embedding
#      12 )
#
# File c:\Users\attam\projects\ERP\.venv\Lib\site-packages\deepface\DeepFace.py:480, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces, l2_normalize, minmax_normalize, cryptosystem)
#     390 def represent(
# ...
